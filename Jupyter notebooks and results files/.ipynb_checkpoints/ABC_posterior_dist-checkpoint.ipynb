# %% [markdown]
# This notebook contains code for generating a posterior distribution of parameter values using approximate Bayesian computation. A summary of this method can be viewed here:
#
#
# Leyshon, Tom. 2021. The ABCs of Approximate Bayesian Computation. Towards Data Science. https://towardsdatascience.com/the-abcs-of-approximate-bayesian-computation-bfe11b8ca341

# %%
#packages
import random 
import sys 
import time 
import os 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import chi2_contingency

# %%
#import the data
#choose a results file
data = pd.read_csv("results3.csv")
#data.columns

# %%
data.head(50)
# Out:
#      ticks  fibrosis-score  alv-count  final-thy1n  final-thy1p  \
# 0    730.0             1.0        0.0          0.0        150.0
# 1   1095.0             1.0        0.0          0.0        150.0
# 2    365.0             1.0        0.0          0.0        150.0
# 3    730.0             1.0        0.0          0.0        150.0
# 4   1095.0             1.0        0.0          0.0        150.0
# 5    365.0             1.0        0.0          0.0        150.0
# 6    730.0             1.0        0.0          0.0        150.0
# 7   1095.0             1.0        0.0          0.0        150.0
# 8    365.0             1.0        0.0          0.0        150.0
# 9    730.0             1.0        0.0          0.0        150.0
# 10  1095.0             1.0        0.0          0.0        150.0
# 11   365.0             1.0        0.0          0.0        150.0
# 12   730.0             1.0        0.0          0.0        150.0
# 13  1095.0             1.0        0.0          0.0        150.0
# 14   365.0             1.0        0.0          0.0        150.0
# 15   730.0             1.0        0.0          0.0        150.0
# 16  1095.0             1.0        0.0          0.0        150.0
# 17   365.0             1.0        0.0          0.0        150.0
# 18   730.0             1.0        0.0          0.0        150.0
# 19  1095.0             1.0        0.0          0.0        150.0
# 20  1095.0             1.0        0.0          0.0        150.0
# 21   365.0             1.0        0.0          0.0        150.0
# 22   730.0             1.0        0.0          0.0        150.0
# 23  1095.0             1.0        0.0          0.0        150.0
# 24   730.0             1.0        0.0          0.0        150.0
# 25   730.0             1.0        0.0          0.0        150.0
# 26   365.0             1.0        0.0          0.0        150.0
# 27   730.0             1.0        0.0          0.0        150.0
# 28   730.0             1.0        0.0          0.0        150.0
# 29  1095.0             1.0        0.0          0.0        150.0
# 30   365.0             1.0        0.0          0.0        150.0
# 31   730.0             1.0        0.0          0.0        150.0
# 32  1095.0             1.0        0.0          0.0        150.0
# 33  1095.0             1.0        0.0          0.0        150.0
# 34   730.0             1.0        0.0          0.0        150.0
# 35   365.0             1.0        0.0          0.0        150.0
# 36  1095.0             1.0        0.0          0.0        150.0
# 37   365.0             1.0        0.0          0.0        150.0
# 38  1095.0             1.0        0.0          0.0        150.0
# 39   730.0             1.0        0.0          0.0        150.0
# 40   365.0             1.0        0.0          0.0        150.0
# 41  1095.0             1.0        0.0          0.0        150.0
# 42   730.0             1.0        0.0          0.0        150.0
# 43   365.0             1.0        0.0          0.0        150.0
# 44   365.0             1.0        0.0          0.0        150.0
# 45   730.0             1.0        0.0          0.0        150.0
# 46  1095.0             1.0        0.0          0.0        150.0
# 47   365.0             1.0        0.0          0.0        150.0
# 48   730.0             1.0        0.0          0.0        150.0
# 49  1095.0             1.0        0.0          0.0        150.0
#
#                                        Setup Commands   Run  Param Value
# 0   reset-ticks setup set thy1ps-count 100 set thy...  1941         0.05
# 1   reset-ticks setup set thy1ps-count 100 set thy...  1917         0.05
# 2   reset-ticks setup set thy1ps-count 100 set thy...  1916         0.05
# 3   reset-ticks setup set thy1ps-count 100 set thy...  1916         0.05
# 4   reset-ticks setup set thy1ps-count 100 set thy...  1916         0.05
# 5   reset-ticks setup set thy1ps-count 100 set thy...  1915         0.05
# 6   reset-ticks setup set thy1ps-count 100 set thy...  1915         0.05
# 7   reset-ticks setup set thy1ps-count 100 set thy...  1915         0.05
# 8   reset-ticks setup set thy1ps-count 100 set thy...  1914         0.05
# 9   reset-ticks setup set thy1ps-count 100 set thy...  1914         0.05
# 10  reset-ticks setup set thy1ps-count 100 set thy...  1914         0.05
# 11  reset-ticks setup set thy1ps-count 100 set thy...  1913         0.05
# 12  reset-ticks setup set thy1ps-count 100 set thy...  1913         0.05
# 13  reset-ticks setup set thy1ps-count 100 set thy...  1913         0.05
# 14  reset-ticks setup set thy1ps-count 100 set thy...  1912         0.05
# 15  reset-ticks setup set thy1ps-count 100 set thy...  1912         0.05
# 16  reset-ticks setup set thy1ps-count 100 set thy...  1912         0.05
# 17  reset-ticks setup set thy1ps-count 100 set thy...  1911         0.05
# 18  reset-ticks setup set thy1ps-count 100 set thy...  1911         0.05
# 19  reset-ticks setup set thy1ps-count 100 set thy...  1911         0.05
# 20  reset-ticks setup set thy1ps-count 100 set thy...  1933         0.05
# 21  reset-ticks setup set thy1ps-count 100 set thy...  1921         0.05
# 22  reset-ticks setup set thy1ps-count 100 set thy...  1921         0.05
# 23  reset-ticks setup set thy1ps-count 100 set thy...  1921         0.05
# 24  reset-ticks setup set thy1ps-count 100 set thy...  1917         0.05
# 25  reset-ticks setup set thy1ps-count 100 set thy...  1933         0.05
# 26  reset-ticks setup set thy1ps-count 100 set thy...  1917         0.05
# 27  reset-ticks setup set thy1ps-count 100 set thy...  1918         0.05
# 28  reset-ticks setup set thy1ps-count 100 set thy...  1909         0.05
# 29  reset-ticks setup set thy1ps-count 100 set thy...  1909         0.05
# 30  reset-ticks setup set thy1ps-count 100 set thy...  1908         0.05
# 31  reset-ticks setup set thy1ps-count 100 set thy...  1908         0.05
# 32  reset-ticks setup set thy1ps-count 100 set thy...  1908         0.05
# 33  reset-ticks setup set thy1ps-count 100 set thy...  1940         0.05
# 34  reset-ticks setup set thy1ps-count 100 set thy...  1940         0.05
# 35  reset-ticks setup set thy1ps-count 100 set thy...  1940         0.05
# 36  reset-ticks setup set thy1ps-count 100 set thy...  1941         0.05
# 37  reset-ticks setup set thy1ps-count 100 set thy...  1941         0.05
# 38  reset-ticks setup set thy1ps-count 100 set thy...  1942         0.05
# 39  reset-ticks setup set thy1ps-count 100 set thy...  1942         0.05
# 40  reset-ticks setup set thy1ps-count 100 set thy...  1942         0.05
# 41  reset-ticks setup set thy1ps-count 100 set thy...  1943         0.05
# 42  reset-ticks setup set thy1ps-count 100 set thy...  1943         0.05
# 43  reset-ticks setup set thy1ps-count 100 set thy...  1943         0.05
# 44  reset-ticks setup set thy1ps-count 100 set thy...  1919         0.05
# 45  reset-ticks setup set thy1ps-count 100 set thy...  1919         0.05
# 46  reset-ticks setup set thy1ps-count 100 set thy...  1919         0.05
# 47  reset-ticks setup set thy1ps-count 100 set thy...  1910         0.05
# 48  reset-ticks setup set thy1ps-count 100 set thy...  1910         0.05
# 49  reset-ticks setup set thy1ps-count 100 set thy...  1910         0.05

# %%
#separate the data frame by number of ticks
data365 = data[data['ticks'] == 365]
data730 = data[data['ticks'] == 730]
data1095 = data[data['ticks'] == 1095]

# %%
data1095['fibrosis-score'].value_counts()
# Out:
# 1.0    3560
# 3.0      40
# Name: fibrosis-score, dtype: int64

# %%
data730['fibrosis-score'].value_counts()
# Out:
# 1.0    3560
# 3.0      40
# Name: fibrosis-score, dtype: int64

# %%
data365['fibrosis-score'].value_counts()
# Out:
# 1.0    3560
# 3.0      27
# 2.0      13
# Name: fibrosis-score, dtype: int64

# %%
#make a list of unique parameter values
sampled_values = data365['Param Value'].unique()
len(sampled_values) #should be 100 - if not, some values were randomly sampled twice
# Out:
# 97

# %%
#define a function that filters the data to only the entries with the selected param
def filter_param(df, param):
    '''
    Purpose: Filter the full data frame to only the values of interest
    Inputs:
        df = full data frame
        param = param value to filter on
    Output: filtered data frame
    '''
    
    orig_df = df
    filtered_df = orig_df[orig_df['Param Value'] == param]
    
    return filtered_df

# %%
#define a function that calculates the p-value for chi-sq test
def chisq(df, param):
    '''
    Purpose: Determine whether the distribution of fibrosis scores in simulated data is significantly different from the validation data
    Input: 
        df = data frame containing all the simulations with a single sampled value of the parameter
        param = param value that has been used to filter
    Output: pvalue
    '''
    param = param
    
    #set validation data
    val_FS1 = 6
    val_FS2 = 8
    val_FS3 = 22
    
    #capture the number of FS=1, FS=2, FS=3
    value_counts_series = df['fibrosis-score'].value_counts()

    # Use the get() method to retrieve the counts of each FS. 
    #If one value doesn't exist, assign 0.
    FS1 = value_counts_series.get(1, 0)
    FS2 = value_counts_series.get(2, 0)
    FS3 = value_counts_series.get(3, 0)    
    
    #check to make sure they sum to 36
    if FS1 + FS2 + FS3 != 36:
        print('Problem with ', param)
    else:
        pass
        
    #set up contingency table for the test
    contingency_table = np.array([[val_FS1, val_FS2, val_FS3], #validation data
                                    [FS1, FS2, FS3]])  # simulation data

    # Perform the chi-squared test
    chi2, pvalue, dof, expected = chi2_contingency(contingency_table)
    return pvalue

# %%
#Analysis of 1095 step timepoint

posterior_dist = []

#loop through values in list
for param in sampled_values:
    
    #filter the original df for each sampled value
    filtered_df = filter_param(data1095, param)
    
    #determine if distribution of fibrosis scores is significantly different from validation
    pvalue = chisq(filtered_df, param)
    
    # if NSD, add to the posterior distribution
    if pvalue>0.05: 
        posterior_dist.append(param)
# Out:
# Problem with  2.59
# Problem with  3.62
# Problem with  7.93

# %%
#see the posterior distribution
posterior_dist
# Out:
# []

# %%
#see what's going on with problematic parameter values
newdata = filter_param(data1095, 2.59)
len(newdata) #this value was randomly sampled twice
#later experiments have sampled values rounded to 3 digits, to help reduce this problem
# Out:
# 72
